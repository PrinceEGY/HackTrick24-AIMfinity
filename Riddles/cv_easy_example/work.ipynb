# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
import json
import time
from cv_easy import *

# %%
with open("img_log1.txt", "r") as f:
    js = json.loads(f.read().replace("'", '"'))['test_case']

# %%
img = np.array(js[0], dtype = np.uint8)

# %%
img.shape
# Out:
# (1152, 768, 3)

# %%
plt.imshow(img);

# %%
import time
start = time.time()
order, batches = reorder_shards(img, 12)
print(time.time() - start)
# Out:
# 0.013677835464477539

# %%
plt.imshow(img);

# %%
plt.imshow(np.concatenate([batches[i] for i in order], axis = 1));
